# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e1c48ad5406f> in <module>
#       7
#       8 # Import API key
# ----> 9 from api_keys import api_key
#      10
#      11 # Incorporated citipy to determine city based on latitude and longitude
#
# ModuleNotFoundError: No module named 'api_keys'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
  
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key


# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=vila franca do campo
# Processing Record 2 | Brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=brae
# Processing Record 3 | Nyuksenitsa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=nyuksenitsa
# Processing Record 4 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=yulara
# City not found. Skipping...
# Processing Record 5 | Shakawe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=shakawe
# Processing Record 6 | Neiafu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=neiafu
# Processing Record 7 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=new norfolk
# Processing Record 8 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=busselton
# Processing Record 9 | Bagala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=bagala
# Processing Record 10 | Nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=nishihara
# Processing Record 11 | Okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=okhotsk
# Processing Record 12 | Porto Novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=porto novo
# Processing Record 13 | Gryfino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=gryfino
# Processing Record 14 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=port blair
# Processing Record 15 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=kodiak
# Processing Record 16 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=port elizabeth
# Processing Record 17 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=provideniya
# Processing Record 18 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=ilulissat
# Processing Record 19 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=atuona
# Processing Record 20 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=barrow
# City not found. Skipping...
# Processing Record 21 | Kysyl-Syr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=kysyl-syr
# Processing Record 22 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=leningradskiy
# Processing Record 23 | Walvis Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=walvis bay
# Processing Record 24 | Yining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=yining
# Processing Record 25 | Aranos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=aranos
# Processing Record 26 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=port alfred
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 27 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=avarua
# Processing Record 28 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=bredasdorp
# Processing Record 29 | Chabahar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=chabahar
# Processing Record 30 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=isangel
# Processing Record 31 | Salinas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=salinas
# Processing Record 32 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=carnarvon
# Processing Record 33 | Qandala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=qandala
# Processing Record 34 | Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=beringovskiy
# Processing Record 35 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=mar del plata
# Processing Record 36 | Francisco Sa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=francisco sa
# Processing Record 37 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=mataura
# Processing Record 38 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=aklavik
# Processing Record 39 | Maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=maragogi
# Processing Record 40 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=hobart
# Processing Record 41 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=rikitea
# Processing Record 42 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=lagoa
# Processing Record 43 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=bandarbeyla
# Processing Record 44 | Novaya Bryan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=novaya bryan
# Processing Record 45 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=punta arenas
# Processing Record 46 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=saint george
# Processing Record 47 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=vaini
# Processing Record 48 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=airai
# Processing Record 49 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=ponta do sol
# Processing Record 50 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=hermanus
# Processing Record 51 | Mazagao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=mazagao
# Processing Record 52 | Trogir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=trogir
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 53 | Sambava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=sambava
# Processing Record 54 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=albany
# Processing Record 55 | Opuwo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=opuwo
# Processing Record 56 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=ushuaia
# Processing Record 57 | Wick
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=wick
# Processing Record 58 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=yellowknife
# Processing Record 59 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=cayenne
# Processing Record 60 | Kondinskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=kondinskoye
# Processing Record 61 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=salalah
# Processing Record 62 | Zhicheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=zhicheng
# City not found. Skipping...
# Processing Record 63 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=longyearbyen
# Processing Record 64 | Samagaltay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=samagaltay
# Processing Record 65 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=jamestown
# Processing Record 66 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=butaritari
# Processing Record 67 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=kapaa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 68 | Singapore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=singapore
# Processing Record 69 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=vao
# Processing Record 70 | Cabra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=cabra
# Processing Record 71 | San Isidro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=san isidro
# Processing Record 72 | Iwaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=iwaki
# Processing Record 73 | Maseru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=maseru
# Processing Record 74 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=tuktoyaktuk
# Processing Record 75 | Cortes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=cortes
# Processing Record 76 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=souillac
# Processing Record 77 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=qaanaaq
# Processing Record 78 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=bluff
# Processing Record 79 | Flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=flinders
# Processing Record 80 | Banda Aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=banda aceh
# Processing Record 81 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=husavik
# City not found. Skipping...
# Processing Record 82 | Balkhash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=balkhash
# Processing Record 83 | Linxia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=linxia
# Processing Record 84 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=hilo
# Processing Record 85 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=ancud
# Processing Record 86 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=tuatapere
# Processing Record 87 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=san patricio
# Processing Record 88 | Non Sang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=non sang
# Processing Record 89 | Margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=margate
# Processing Record 90 | Coos Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=coos bay
# Processing Record 91 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=thompson
# Processing Record 92 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=hasaki
# Processing Record 93 | Mapiripan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=mapiripan
# Processing Record 94 | Road Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=road town
# Processing Record 95 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=victoria
# Processing Record 96 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=chuy
# Processing Record 97 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=naze
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 98 | Manggar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=manggar
# City not found. Skipping...
# Processing Record 99 | Nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=nabire
# Processing Record 100 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=lompoc
# Processing Record 101 | Paramonga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=paramonga
# City not found. Skipping...
# Processing Record 102 | Marienburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=marienburg
# Processing Record 103 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=hithadhoo
# Processing Record 104 | Omboue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=omboue
# Processing Record 105 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=cidreira
# Processing Record 106 | Kissidougou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=kissidougou
# Processing Record 107 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=severo-kurilsk
# Processing Record 108 | Melfort
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=melfort
# Processing Record 109 | Lamu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=lamu
# Processing Record 110 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=sitka
# Processing Record 111 | Matagami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=matagami
# Processing Record 112 | Awbari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=awbari
# Processing Record 113 | Puerto Ayacucho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=puerto ayacucho
# Processing Record 114 | Awjilah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=awjilah
# Processing Record 115 | Werda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=werda
# Processing Record 116 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=meulaboh
# Processing Record 117 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=saskylakh
# Processing Record 118 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=chokurdakh
# Processing Record 119 | Roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=roald
# Processing Record 120 | Puerto Palomas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=puerto palomas
# Processing Record 121 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=bambous virieux
# Processing Record 122 | Seminole
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=seminole
# Processing Record 123 | Pogranichnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=pogranichnyy
# Processing Record 124 | Polunochnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=polunochnoye
# Processing Record 125 | Madang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=madang
# Processing Record 126 | Axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=axim
# Processing Record 127 | Amuntai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=amuntai
# Processing Record 128 | Ambatondrazaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=ambatondrazaka
# Processing Record 129 | Tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=tura
# Processing Record 130 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=kruisfontein
# Processing Record 131 | Tarrafal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=tarrafal
# Processing Record 132 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=katsuura
# Processing Record 133 | Port Moresby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=port moresby
# Processing Record 134 | Nagato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=nagato
# Processing Record 135 | Peniche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=peniche
# Processing Record 136 | Mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=mogadishu
# Processing Record 137 | Nouakchott
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=nouakchott
# Processing Record 138 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=bethel
# Processing Record 139 | Ishigaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=ishigaki
# Processing Record 140 | Ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=ketchikan
# Processing Record 141 | Nioro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=nioro
# Processing Record 142 | Dinghai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=dinghai
# Processing Record 143 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=cape town
# Processing Record 144 | Asyut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=asyut
# Processing Record 145 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=upernavik
# Processing Record 146 | Sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=sinnamary
# Processing Record 147 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=esperance
# Processing Record 148 | Eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=eureka
# Processing Record 149 | Katherine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=katherine
# City not found. Skipping...
# Processing Record 150 | Patos de Minas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=patos de minas
# Processing Record 151 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=torbay
# Processing Record 152 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=faanui
# Processing Record 153 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=puerto ayora
# Processing Record 154 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=alice springs
# Processing Record 155 | Usolye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=usolye
# Processing Record 156 | Ust-Tsilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=ust-tsilma
# Processing Record 157 | Sao Raimundo das Mangabeiras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=sao raimundo das mangabeiras
# Processing Record 158 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=saint-philippe
# Processing Record 159 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=pevek
# Processing Record 160 | Lakatoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=lakatoro
# Processing Record 161 | Aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=aksarka
# Processing Record 162 | Ust-Ishim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=ust-ishim
# Processing Record 163 | Cabuyaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=cabuyaro
# Processing Record 164 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=nanortalik
# Processing Record 165 | Hanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=hanna
# Processing Record 166 | Ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=ballina
# Processing Record 167 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=saint-augustin
# Processing Record 168 | Somerset
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=somerset
# Processing Record 169 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=georgetown
# Processing Record 170 | Emerald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=emerald
# Processing Record 171 | Auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=auki
# Processing Record 172 | Bargi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=bargi
# Processing Record 173 | Dubai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=dubai
# Processing Record 174 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=hamilton
# Processing Record 175 | Basoko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=basoko
# Processing Record 176 | Selma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=selma
# Processing Record 177 | Dukat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=dukat
# Processing Record 178 | Gornyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=gornyy
# Processing Record 179 | Thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=thinadhoo
# Processing Record 180 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=cockburn town
# Processing Record 181 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=narsaq
# Processing Record 182 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=ribeira grande
# Processing Record 183 | Zhangye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=zhangye
# Processing Record 184 | Zima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=zima
# Processing Record 185 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=east london
# Processing Record 186 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=mahebourg
# Processing Record 187 | Igarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=igarka
# City not found. Skipping...
# Processing Record 188 | Iskateley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=iskateley
# Processing Record 189 | Maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=maniitsoq
# Processing Record 190 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=khatanga
# Processing Record 191 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=arraial do cabo
# City not found. Skipping...
# Processing Record 192 | Palu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=palu
# Processing Record 193 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=lorengau
# Processing Record 194 | Quepos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=quepos
# City not found. Skipping...
# Processing Record 195 | Fort Frances
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=fort frances
# Processing Record 196 | Kupang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=kupang
# Processing Record 197 | Port Macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=port macquarie
# City not found. Skipping...
# Processing Record 198 | Inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=inhambane
# Processing Record 199 | Buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=buraydah
# Processing Record 200 | Tabuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=tabuk
# Processing Record 201 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=tiksi
# Processing Record 202 | Mangrol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=mangrol
# Processing Record 203 | Zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=zhangjiakou
# Processing Record 204 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=vardo
# Processing Record 205 | Yamoussoukro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=yamoussoukro
# Processing Record 206 | Chumikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=chumikan
# Processing Record 207 | Kasempa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=kasempa
# Processing Record 208 | Camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=camacha
# Processing Record 209 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=kaitangata
# Processing Record 210 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=cabo san lucas
# Processing Record 211 | Itupiranga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=itupiranga
# Processing Record 212 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=dikson
# Processing Record 213 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=hobyo
# Processing Record 214 | Gazli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=gazli
# Processing Record 215 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=vila velha
# Processing Record 216 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=geraldton
# Processing Record 217 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=ostrovnoy
# Processing Record 218 | Ngunguru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=ngunguru
# Processing Record 219 | Atambua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=atambua
# Processing Record 220 | Iroquois Falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=iroquois falls
# Processing Record 221 | Kidal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=kidal
# Processing Record 222 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=castro
# Processing Record 223 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=luderitz
# Processing Record 224 | Nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=nhulunbuy
# City not found. Skipping...
# Processing Record 225 | Yanam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=yanam
# Processing Record 226 | Mackay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=mackay
# Processing Record 227 | Port Hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=port hedland
# Processing Record 228 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=klaksvik
# Processing Record 229 | Dinan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=dinan
# Processing Record 230 | Gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=gat
# Processing Record 231 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=guerrero negro
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 232 | Mezen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=mezen
# Processing Record 233 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=kahului
# Processing Record 234 | Tosno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=tosno
# Processing Record 235 | Oktyabrskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=oktyabrskoye
# Processing Record 236 | Mbandaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=mbandaka
# Processing Record 237 | Taihe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=taihe
# Processing Record 238 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=codrington
# Processing Record 239 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=te anau
# City not found. Skipping...
# Processing Record 240 | Usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=usinsk
# Processing Record 241 | Nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=nemuro
# Processing Record 242 | Dashitou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=dashitou
# Processing Record 243 | Strezhevoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=strezhevoy
# Processing Record 244 | Nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=nantucket
# Processing Record 245 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=nikolskoye
# Processing Record 246 | Askino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=askino
# Processing Record 247 | Carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=carutapera
# Processing Record 248 | Gigmoto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=gigmoto
# Processing Record 249 | Nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=nouadhibou
# Processing Record 250 | Sharjah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=sharjah
# Processing Record 251 | Bima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=bima
# Processing Record 252 | Keokuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=keokuk
# Processing Record 253 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=lebu
# City not found. Skipping...
# Processing Record 254 | Straseni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=straseni
# Processing Record 255 | Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=barra
# Processing Record 256 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=bathsheba
# Processing Record 257 | Vysokogornyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=vysokogornyy
# Processing Record 258 | Sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=sechura
# Processing Record 259 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=sao joao da barra
# Processing Record 260 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=saldanha
# Processing Record 261 | Yingcheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=yingcheng
# City not found. Skipping...
# Processing Record 262 | Xichang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=xichang
# Processing Record 263 | Capaccio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=capaccio
# Processing Record 264 | Namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=namibe
# Processing Record 265 | Tommot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=tommot
# Processing Record 266 | Tateyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=tateyama
# Processing Record 267 | Tuusula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=tuusula
# Processing Record 268 | Perth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=perth
# Processing Record 269 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=srednekolymsk
# Processing Record 270 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=coquimbo
# Processing Record 271 | Oussouye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=oussouye
# City not found. Skipping...
# Processing Record 272 | Dalfsen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=dalfsen
# Processing Record 273 | Tubmanburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=tubmanburg
# Processing Record 274 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=los llanos de aridane
# Processing Record 275 | Atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=atar
# Processing Record 276 | Warmbad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=warmbad
# Processing Record 277 | Trzic
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=trzic
# Processing Record 278 | Sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=sur
# Processing Record 279 | Katobu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=katobu
# Processing Record 280 | Glyadyanskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=glyadyanskoye
# Processing Record 281 | Rincon Viejo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=rincon viejo
# Processing Record 282 | La Ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=la ronge
# City not found. Skipping...
# Processing Record 283 | Adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=adrar
# Processing Record 284 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=hambantota
# City not found. Skipping...
# Processing Record 285 | Tandil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=tandil
# Processing Record 286 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=dunedin
# Processing Record 287 | Kinkala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=kinkala
# Processing Record 288 | Grand Gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=grand gaube
# Processing Record 289 | Lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=lasa
# Processing Record 290 | Baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=baykit
# Processing Record 291 | Taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=taoudenni
# Processing Record 292 | Faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=faya
# City not found. Skipping...
# Processing Record 293 | Monforte de Lemos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=monforte de lemos
# Processing Record 294 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=caravelas
# Processing Record 295 | Pingliang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=pingliang
# Processing Record 296 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=pisco
# Processing Record 297 | Mapimi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=mapimi
# City not found. Skipping...
# Processing Record 298 | Tooele
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=tooele
# Processing Record 299 | Nizwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=nizwa
# Processing Record 300 | Haines Junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=haines junction
# Processing Record 301 | Mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=mitsamiouli
# Processing Record 302 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=lavrentiya
# Processing Record 303 | Pangkalanbuun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=pangkalanbuun
# Processing Record 304 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=hofn
# Processing Record 305 | Seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=seoul
# Processing Record 306 | Santa Isabel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=santa isabel
# Processing Record 307 | Puerto del Rosario
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=puerto del rosario
# City not found. Skipping...
# Processing Record 308 | Gaoua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=gaoua
# Processing Record 309 | Deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=deputatskiy
# Processing Record 310 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=pangnirtung
# Processing Record 311 | Bemidji
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=bemidji
# Processing Record 312 | Pocatello
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=pocatello
# Processing Record 313 | Kandry
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=kandry
# Processing Record 314 | Uyemskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=uyemskiy
# Processing Record 315 | Vannes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=vannes
# Processing Record 316 | Qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=qaqortoq
# Processing Record 317 | Jacareacanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=jacareacanga
# Processing Record 318 | Santa Cruz Cabralia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=santa cruz cabralia
# Processing Record 319 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=alofi
# Processing Record 320 | Can
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=can
# Processing Record 321 | Ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=ugoofaaru
# Processing Record 322 | Lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=lata
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 323 | Cartagena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=cartagena
# Processing Record 324 | Puerto Colombia
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=rio gallegos
# Processing Record 448 | Caceres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=caceres
# Processing Record 449 | Necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=necochea
# Processing Record 450 | Luena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=luena
# Processing Record 451 | Tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=tiznit
# Processing Record 452 | Groton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=groton
# Processing Record 453 | Birin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=birin
# Processing Record 454 | Kolosovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=kolosovka
# Processing Record 455 | Kaspiyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=kaspiyskiy
# Processing Record 456 | Coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=coihaique
# Processing Record 457 | Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=komsomolskiy
# Processing Record 458 | Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=saint-pierre
# City not found. Skipping...
# Processing Record 459 | Orissaare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=orissaare
# Processing Record 460 | Parakai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=parakai
# City not found. Skipping...
# Processing Record 461 | Solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=solnechnyy
# Processing Record 462 | Muroto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=muroto
# Processing Record 463 | Luau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=luau
# Processing Record 464 | Muriti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=muriti
# Processing Record 465 | Flin Flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=flin flon
# Processing Record 466 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=norman wells
# Processing Record 467 | Santa Maria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=santa maria
# Processing Record 468 | Cam Ranh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=cam ranh
# Processing Record 469 | Porto Walter
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=porto walter
# Processing Record 470 | Valdosta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=valdosta
# Processing Record 471 | Grenada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=grenada
# Processing Record 472 | Mayumba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=mayumba
# Processing Record 473 | Verkhnevilyuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=verkhnevilyuysk
# Processing Record 474 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=fortuna
# Processing Record 475 | Yagodnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=yagodnoye
# City not found. Skipping...
# Processing Record 476 | Romitan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=romitan
# Processing Record 477 | Villa Carlos Paz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=villa carlos paz
# Processing Record 478 | Bahia Honda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=bahia honda
# Processing Record 479 | Chistogorskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=chistogorskiy
# City not found. Skipping...
# Processing Record 480 | Kralendijk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=kralendijk
# Processing Record 481 | Japura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=japura
# Processing Record 482 | Am Timan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=am timan
# Processing Record 483 | Charters Towers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=charters towers
# Processing Record 484 | Najran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=najran
# Processing Record 485 | Tadine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=tadine
# Processing Record 486 | Osypenko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=osypenko
# Processing Record 487 | Suoyarvi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=suoyarvi
# Processing Record 488 | Stare Mesto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=stare mesto
# Processing Record 489 | Mporokoso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=mporokoso
# Processing Record 490 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=cherskiy
# Processing Record 491 | Imeni Poliny Osipenko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=imeni poliny osipenko
# Processing Record 492 | Tygda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=tygda
# Processing Record 493 | Sibiti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=sibiti
# Processing Record 494 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=dingle
# Processing Record 495 | Christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=christchurch
# City not found. Skipping...
# Processing Record 496 | Porto Velho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=porto velho
# Processing Record 497 | Hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=hami
# Processing Record 498 | Bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=bilma
# Processing Record 499 | Nyaunglebin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=nyaunglebin
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 500 | San Martin Sacatepequez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=san martin sacatepequez
# Processing Record 501 | Sorong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=sorong
# Processing Record 502 | Luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=luanda
# Processing Record 503 | Kailua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=kailua
# Processing Record 504 | Hashtrud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=hashtrud
# Processing Record 505 | Moyale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=moyale
# Processing Record 506 | Pecos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=pecos
# Processing Record 507 | Santa Helena de Goias
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=santa helena de goias
# Processing Record 508 | Taksimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=taksimo
# Processing Record 509 | Boditi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=boditi
# Processing Record 510 | Takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=takoradi
# Processing Record 511 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=kavaratti
# Processing Record 512 | Maniwaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=maniwaki
# Processing Record 513 | Monchegorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=monchegorsk
# Processing Record 514 | Amposta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=amposta
# Processing Record 515 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=clyde river
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 516 | Lagos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=lagos
# Processing Record 517 | Suamico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=suamico
# Processing Record 518 | Zakamensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=zakamensk
# Processing Record 519 | Dakar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=dakar
# Processing Record 520 | Ponta Delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=ponta delgada
# Processing Record 521 | Nyurba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=nyurba
# Processing Record 522 | Pakpattan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=pakpattan
# Processing Record 523 | Portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=portland
# Processing Record 524 | Newala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=newala
# Processing Record 525 | Moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=moron
# Processing Record 526 | Merauke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=merauke
# Processing Record 527 | Gazanjyk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=gazanjyk
# Processing Record 528 | Mumford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=mumford
# Processing Record 529 | Novyy Urengoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=novyy urengoy
# Processing Record 530 | San Vicente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=san vicente
# Processing Record 531 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=pacific grove
# Processing Record 532 | Kallithea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=kallithea
# Processing Record 533 | Prince Rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=prince rupert
# Processing Record 534 | Kholmogory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=kholmogory
# Processing Record 535 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=vanimo
# Processing Record 536 | Granada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=granada
# Processing Record 537 | Vilhena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=vilhena
# Processing Record 538 | Gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=gamba
# Processing Record 539 | Dumfries
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=dumfries
# Processing Record 540 | Pouebo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=pouebo
# Processing Record 541 | Bandrele
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=bandrele
# Processing Record 542 | Tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=tautira
# Processing Record 543 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=yar-sale
# Processing Record 544 | Zemio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=zemio
# Processing Record 545 | Nanjing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=nanjing
# Processing Record 546 | Tam Ky
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=tam ky
# Processing Record 547 | Pyu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=pyu
# Processing Record 548 | Gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=gizo
# City not found. Skipping...
# Processing Record 549 | The Pas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=the pas
# Processing Record 550 | Mpulungu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=mpulungu
# Processing Record 551 | Westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=westport
# Processing Record 552 | Molteno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=molteno
# Processing Record 553 | Vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=vostok
# Processing Record 554 | Seddon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dbb80371445f2c8c45a8fb69a809b79a&q=seddon

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

df=pd.DataFrame(weatherpy_dict)
df.to_csv("output_data_file")
df.head()
# Out:
#                    City  Cloudiness Country        Date  Humidity    Lat  \
# 0  Vila Franca do Campo          40      PT  1567719516        77  37.72
# 1                  Brae         100      GB  1567719517        93  60.40
# 2           Nyuksenitsa         100      RU  1567719519        98  60.41
# 3                Yulara           0      AU  1567719520        43 -25.24
# 4               Shakawe           0      BW  1567719521        19 -18.36
#
#       Lng  Max Temp  Wind Speed
# 0  -25.43     71.01        5.82
# 1   -1.35     53.60       13.87
# 2   44.24     52.89        1.77
# 3  130.99     51.80       12.75
# 4   21.84     70.17        5.57

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(df["Lat"], df["Max Temp"], marker ="o", s=10)


plt.title("City Latitude vs. Max Temp")
plt.ylabel("Max. Temp (F)")
plt.xlabel("Latitide")
plt.grid(True)

plt.savefig("MaxTempVSLat.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(df["Lat"], df["Humidity"], marker="o", s=10)

plt.title("Latitude vs. Humidity")
plt.ylabel("Humidity %")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("HumidityVSLatitude")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(df["Lat"], df["Cloudiness"], marker="o", s=10)

plt.title("City Latitude VS Cloudiness")
plt.ylabel("Cloudiness %")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("CloudinessVSLat")

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(df["Lat"], df["Wind Speed"], marker="o", s=10)

plt.title("City Latitude vs Wind Speed")
plt.ylabel("Wind Speed (MPH)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Wind_Speed_VS_Lat")

plt.show()
